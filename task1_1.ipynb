# %%
import pandas as pd
import matplotlib.pyplot as plt

# Provide the full path to the CSV file
file_path1 = r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\LAYING\Subject_1.csv'
file_path2=r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\SITTING\Subject_1.csv'
file_path3=r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\STANDING\Subject_1.csv'


file_path4=r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\WALKING\Subject_1.csv'


file_path5=r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\WALKING_DOWNSTAIRS\Subject_1.csv'
file_path6=r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\WALKING_UPSTAIRS\Subject_1.csv'







# Read the CSV file
df1 = pd.read_csv(file_path1)


plt.plot(df1['accx'])
plt.plot(df1['accy'])
plt.plot(df1['accz'])
plt.xlabel('Time')
plt.ylabel('Acceleration')

plt.show()


df2 = pd.read_csv(file_path2)

# Plot the data (assuming the CSV has columns 'x' and 'y')
plt.plot(df2['accx'])

plt.plot(df2['accy'])
plt.plot(df2['accz'])
plt.xlabel('Time')
plt.ylabel('Acceleration')


plt.show()

df3 = pd.read_csv(file_path3)

plt.plot(df3['accx'])
plt.plot(df3['accy'])
plt.plot(df3['accz'])
plt.xlabel('Time')
plt.ylabel('Acceleration')

plt.show()

df4 = pd.read_csv(file_path4)


plt.plot(df4['accx'])
plt.plot(df4['accy'])
plt.plot(df4['accz'])
plt.xlabel('Time')
plt.ylabel('Acceleration')

plt.show()

df5 = pd.read_csv(file_path5)


plt.plot(df5['accx']) 
plt.plot(df5['accy'])
plt.plot(df5['accz'])
plt.xlabel('Time')
plt.ylabel('Acceleration')

plt.show()

df6 = pd.read_csv(file_path6)


plt.plot(df6['accx'])
plt.plot(df6['accy'])
plt.plot(df6['accz'])
plt.xlabel('Time')
plt.ylabel('Acceleration')

plt.show()

# %% [markdown]
# 3d plot

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
time = np.linspace(0, 10, 100) 
file_path1 = r'C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train\LAYING\Subject_1.csv'

# Creating a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(time, acceleration_x, acceleration_y, label='X vs Y')
ax.plot(time, accx, acceleration_z, label='X vs Z')
ax.plot(time, accy, acceleration_z, label='Y vs Z')

ax.set_xlabel('Time (s)')
ax.set_ylabel('Acceleration X (m/s^2)')
ax.set_zlabel('Acceleration Y/Z (m/s^2)')
ax.legend()

plt.show()
