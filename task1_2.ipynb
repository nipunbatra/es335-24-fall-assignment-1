# %% [markdown]
#  Do you think we need a machine learning model to differentiate between static activities (laying, sitting, standing) and dynamic activities(walking, walking_downstairs, walking_upstairs)? Look at the linear acceleration $(acc_x^2+acc_y^2+acc_z^2)$ for each activity and justify your answer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

base_dir = r"C:\Users\suruc\OneDrive\Desktop\ML_Assignment\Combined\Train"

# Initialize lists to hold data and labels
data = []
labels = []

# Iterate through each activity class folder
for activity in os.listdir(base_dir):
    activity_dir = os.path.join(base_dir, activity)

    # Iterate through each subject file in the activity folder
    for file_name in os.listdir(activity_dir):
        file_path = os.path.join(activity_dir, file_name)

        # Load the CSV file
        df = pd.read_csv(file_path)

        # Compute total acceleration
        df['linear_accel'] = df['accx']**2 + df['accy']**2 + df['accz']**2
       

def classify_activity(linear_accel):
    if linear_accel < 2:  # Example threshold, adjust based on your analysis
        return 'LAYING'
    elif linear_accel < 5:
        return 'SITTING'
    elif linear_accel < 8:
        return 'STANDING'
    else:
        return 'WALKING'

# Apply the rule-based classifier
df['predicted_activity'] = df['linear_accel'].apply(classify_activity)

# Visualize the prediction results
plt.figure(figsize=(22, 38))
df.boxplot(column='linear_accel', by='predicted_activity', grid=False)
plt.title('Linear Acceleration by Predicted Activity')
plt.suptitle('')
plt.xlabel('Predicted Activity')
plt.ylabel('Linear Acceleration')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# since these activities can be predicted easily using rule basedclassification  we don't need a machin elearningmodelto show them
